# %%
import pandas as pd
from matplotlib import pyplot
series = pd.read_csv('D:\CURSURI\SERII DE TIMP\passengers_RO.csv', header=0)
yt=pd.DataFrame(series["Pasageri"])
yt.plot()
pyplot.show()
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(yt, freq=12, model='multiplicative')
result.plot()
pyplot.show()
